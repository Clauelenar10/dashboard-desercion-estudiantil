# %% [markdown]
# # Crear base de datos

# %%
import pandas as pd
import json
from tqdm import tqdm

# %%
df_estudiantes = pd.read_excel("ESTUDIANTES.xlsx")
df_materias = pd.read_excel("MATERIAS.xlsx")

# %%
df_estudiantes
# Out:
#            ID  PERIODO  EDAD SEXO  SEMESTRE     TIPO_ESTUDIANTE  \
# 0      409967   202510    17    F       1.0  Estudiante regular
# 1      410620   202510    18    M       1.0  Estudiante regular
# 2      410657   202510    17    F       1.0  Estudiante regular
# 3      415629   202510    18    M       1.0  Estudiante regular
# 4      415712   202510    18    M       1.0  Estudiante regular
# ...       ...      ...   ...  ...       ...                 ...
# 10221  370043   202510    24    F       7.0  Estudiante regular
# 10222  361636   202510    22    M       5.0  Estudiante regular
# 10223  320707   202510    24    F      11.0  Estudiante regular
# 10224  322728   202510    22    M       9.0  Estudiante regular
# 10225  410922   202510    19    M       1.0  Estudiante regular
#
#                TIPO_ADMISION                    PROGRAMA PROGRAMA2  ESTRATO  \
# 0         Ordinaria Pregrado                     Derecho       NaN        5
# 1         Ordinaria Pregrado                    Geología       NaN        1
# 2         Ordinaria Pregrado                 Odontología       NaN        2
# 3         Ordinaria Pregrado       Ingeniería Industrial       NaN        4
# 4         Ordinaria Pregrado                    Economía       NaN        4
# ...                      ...                         ...       ...      ...
# 10221  Transferencia Externa         Ingeniería Mecánica       NaN        4
# 10222     Ordinaria Pregrado                  Psicología       NaN        4
# 10223     Ordinaria Pregrado                    Medicina       NaN        4
# 10224     Ordinaria Pregrado  Administración de Empresas       NaN        6
# 10225     Ordinaria Pregrado       Ingeniería Industrial       NaN        5
#
#        ...  ICFES ICFES MT ICFES LC ICFES SC  ICFES CN ICFES ING DISCAPACIDAD  \
# 0      ...  213.0     46.0     37.0     43.0      41.0      54.0  00- Ninguno
# 1      ...  257.0     60.0     52.0     43.0      49.0      56.0  00- Ninguno
# 2      ...  380.0     77.0     74.0     75.0      70.0     100.0  00- Ninguno
# 3      ...  374.0     78.0     74.0     73.0      73.0      78.0  00- Ninguno
# 4      ...  323.0     64.0     65.0     66.0      61.0      72.0  00- Ninguno
# ...    ...    ...      ...      ...      ...       ...       ...          ...
# 10221  ...    NaN      NaN      NaN      NaN       NaN       NaN  00- Ninguno
# 10222  ...    NaN      NaN      NaN      NaN       NaN       NaN  00- Ninguno
# 10223  ...    NaN      NaN      NaN      NaN       NaN       NaN  00- Ninguno
# 10224  ...    NaN      NaN      NaN      NaN       NaN       NaN  00- Ninguno
# 10225  ...    NaN      NaN      NaN      NaN       NaN       NaN  00- Ninguno
#
#       GRADUADO  DESERTOR         BECADO
# 0            0         0      No becado
# 1            0         1      No becado
# 2            0         0  Institucional
# 3            0         0  Institucional
# 4            0         0      No becado
# ...        ...       ...            ...
# 10221        0         0      No becado
# 10222        0         0      No becado
# 10223        0         0      No becado
# 10224        1         0      No becado
# 10225        0         0      No becado
#
# [10226 rows x 28 columns]

# %%
df_estudiantes.columns = df_estudiantes.columns.str.strip()
df_materias.columns = df_materias.columns.str.strip()

# %%
documentos_json = []
estudiantes_procesados = 0
errores = 0

# %%
# Iterar sobre cada estudiante
for indice, estudiante in tqdm(df_estudiantes.iterrows(), total=len(df_estudiantes), desc="Procesando estudiantes"):
    
    # Extraer ID del estudiante
    estudiante_id = str(estudiante['ID'])
    
   
    
    # Filtrar materias que pertenecen a este estudiante
    materias_del_estudiante = df_materias[df_materias['ID'] == estudiante['ID']]
    
  
    
    # Lista para guardar materias en formato JSON
    materias_array = []
    
    # Variables para métricas
    materias_perdidas_total = 0
    materias_perdidas_por_categoria = {}  # Diccionario para contar por categoría
    codigos_materias_vistas = {}  # Para detectar repeticiones
    materias_repetidas_count = 0
    
    # Procesar cada materia
    for idx_materia, materia in materias_del_estudiante.iterrows():
        
        # Extraer datos de la materia
        nota = materia['NOTA']
        codigo = materia['CODIGO MAERIA']
        nombre_materia = materia['MATERIA']
        categoria = materia['CATEGORIA MATERIA']
        periodo = materia['PERIODO']
        retirada = materia['Retirada']
        
        # Convertir nota a float (si existe)
        if pd.notna(nota):
            nota_numerica = float(nota)
        else:
            nota_numerica = None
        
        # Convertir retirada a entero
        if pd.notna(retirada):
            retirada_valor = int(retirada)
        else:
            retirada_valor = 0
        
        # Crear objeto de materia para el JSON
        materia_objeto = {
            "materia": nombre_materia,
            "codigo_materia": codigo,
            "categoria": categoria,
            "periodo": int(periodo),
            "nota": nota_numerica,
            "retirada": retirada_valor
        }
        
        # Agregar a la lista
        materias_array.append(materia_objeto)
        
        # Lógica de materias perdidas:
        # 1. Retirada: retirada == 1 (nota vacía o 0)
        # 2. Perdida: nota entre 0 y 3 (exclusivo) y NO retirada
        
        materia_perdida = False
        
        if retirada_valor == 1:
            # Materia retirada (sin importar la nota)
            materia_perdida = True
        elif nota_numerica is not None and 0 < nota_numerica < 3.0:
            # Materia perdida (nota mayor a 0 y menor a 3)
            materia_perdida = True
        
        if materia_perdida:
            materias_perdidas_total += 1
            
            # Contar por categoría
            if categoria in materias_perdidas_por_categoria:
                materias_perdidas_por_categoria[categoria] += 1
            else:
                materias_perdidas_por_categoria[categoria] = 1
        
        # Detectar materias repetidas (mismo código más de una vez)
        if codigo in codigos_materias_vistas:
            codigos_materias_vistas[codigo] += 1
        else:
            codigos_materias_vistas[codigo] = 1
    
    # Contar cuántos códigos se repitieron
    for codigo, veces in codigos_materias_vistas.items():
        if veces > 1:
            materias_repetidas_count += 1
    

    
    # Obtener solo las notas válidas (no None y no retiradas)
    notas_validas = []
    for mat in materias_array:
        if mat['nota'] is not None and mat['retirada'] == 0:
            notas_validas.append(mat['nota'])
    
    # Calcular promedio
    if len(notas_validas) > 0:
        promedio_acumulado = sum(notas_validas) / len(notas_validas)
        promedio_acumulado = round(promedio_acumulado, 2)
    else:
        promedio_acumulado = None
    
    
    # Extraer ciudad y país
    ciudad = str(estudiante['CIUDAD']).strip() if pd.notna(estudiante['CIUDAD']) else ""
    pais = str(estudiante['PAIS']).strip() if pd.notna(estudiante['PAIS']) else ""
    
    # Variables binarias
    es_barranquilla = 1 if ciudad.lower() == 'barranquilla' else 0
    es_colombia = 1 if pais.lower() == 'colombia' else 0
   
    
    documento = {
        "_id": estudiante_id,
        
        "datos_personales": {
            "edad": int(estudiante['EDAD']) if pd.notna(estudiante['EDAD']) else None,
            "genero": str(estudiante['SEXO']).strip() if pd.notna(estudiante['SEXO']) else "",
            "estrato": int(estudiante['ESTRATO']) if pd.notna(estudiante['ESTRATO']) else None,
            "discapacidad": str(estudiante['DISCAPACIDAD']).strip() if pd.notna(estudiante['DISCAPACIDAD']) else ""
        },
        
        "academico": {
            "programa": str(estudiante['PROGRAMA']).strip() if pd.notna(estudiante['PROGRAMA']) else "",
            "programa_secundario": str(estudiante['PROGRAMA2']).strip() if pd.notna(estudiante['PROGRAMA2']) else None,
            "semestre_actual": int(estudiante['SEMESTRE']) if pd.notna(estudiante['SEMESTRE']) else None,
            "tipo_estudiante": str(estudiante['TIPO_ESTUDIANTE']).strip() if pd.notna(estudiante['TIPO_ESTUDIANTE']) else "",
            "tipo_admision": str(estudiante['TIPO_ADMISION']).strip() if pd.notna(estudiante['TIPO_ADMISION']) else "",
            "estado_academico": str(estudiante['ESTADO_ACADEMICO']).strip() if pd.notna(estudiante['ESTADO_ACADEMICO']) else ""
        },
        
        "location": {
            "ciudad": ciudad,
            "departamento": str(estudiante['DEPTO']).strip() if pd.notna(estudiante['DEPTO']) else "",
            "pais": pais,
            "es_barranquilla": es_barranquilla,
            "es_colombia": es_colombia,
            "codigo_dane": str(estudiante['CODIGO_DANE']).strip() if pd.notna(estudiante['CODIGO_DANE']) else None
        },
        
        "colegio": {
            "tipo_colegio": str(estudiante['TIPO COLEGIO']).strip() if pd.notna(estudiante['TIPO COLEGIO']) else None,
            "calendario_colegio": str(estudiante['CALENDARIO COLEGIO']).strip() if pd.notna(estudiante['CALENDARIO COLEGIO']) else None,
            "descripcion_bachillerato": str(estudiante['DESC_BACHILLERATO']).strip() if pd.notna(estudiante['DESC_BACHILLERATO']) else None
        },
        
        "ICFES": {
            "puntaje_total": float(estudiante['ICFES']) if pd.notna(estudiante['ICFES']) else None,
            "matematicas": float(estudiante['ICFES MT']) if pd.notna(estudiante['ICFES MT']) else None,
            "lectura_critica": float(estudiante['ICFES LC']) if pd.notna(estudiante['ICFES LC']) else None,
            "sociales": float(estudiante['ICFES SC']) if pd.notna(estudiante['ICFES SC']) else None,
            "ciencias": float(estudiante['ICFES CN']) if pd.notna(estudiante['ICFES CN']) else None,
            "ingles": float(estudiante['ICFES ING']) if pd.notna(estudiante['ICFES ING']) else None
        },
        
        "metricas_rendimiento": {
            "promedio_acumulado": promedio_acumulado,
            "materias_cursadas_total": len(materias_array),
            "materias_perdidas_total": materias_perdidas_total,
            "materias_perdidas_por_departamento": materias_perdidas_por_categoria,
            "materias_repetidas": materias_repetidas_count
        },
        
        "estado": {
            "becado": str(estudiante['BECADO']).strip() if pd.notna(estudiante['BECADO']) else "",
            "graduado": int(estudiante['GRADUADO']) if pd.notna(estudiante['GRADUADO']) else 0,
            "desertor": int(estudiante['DESERTOR']) if pd.notna(estudiante['DESERTOR']) else 0
        },
        
        "periodo_info": {
            "ultimo_periodo": int(estudiante['PERIODO']) if pd.notna(estudiante['PERIODO']) else None
        },
        
        "materias_cursadas": materias_array
    }
    
    
    
    documentos_json.append(documento)
    estudiantes_procesados += 1
# Out:
# Procesando estudiantes: 100%|██████████| 10226/10226 [00:16<00:00, 636.07it/s]
# Procesando estudiantes: 100%|██████████| 10226/10226 [00:16<00:00, 636.07it/s]

# %%
# Guardar con formato 
with open('estudiantes_documentos.json', 'w', encoding='utf-8') as archivo:
    json.dump(documentos_json, archivo, ensure_ascii=False, indent=2)

# %%
print(json.dumps(documentos_json[0], indent=2, ensure_ascii=False))
# Out:
# {
#   "_id": "409967",
#   "datos_personales": {
#     "edad": 17,
#     "genero": "F",
#     "estrato": 5,
#     "discapacidad": "00- Ninguno"
#   },
#   "academico": {
#     "programa": "Derecho",
#     "programa_secundario": null,
#     "semestre_actual": 1,
#     "tipo_estudiante": "Estudiante regular",
#     "tipo_admision": "Ordinaria Pregrado",
#     "estado_academico": "Normal"
#   },
#   "location": {
#     "ciudad": "San Andres",
#     "departamento": "Archipielago de S.A.y Providen",
#     "pais": "Colombia",
#     "es_barranquilla": 0,
#     "es_colombia": 1,
#     "codigo_dane": "388001000673.0"
#   },
#   "colegio": {
#     "tipo_colegio": "PRIVADO",
#     "calendario_colegio": "A",
#     "descripcion_bachillerato": "Gimnasio Real"
#   },
#   "ICFES": {
#     "puntaje_total": 213.0,
#     "matematicas": 46.0,
#     "lectura_critica": 37.0,
#     "sociales": 43.0,
#     "ciencias": 41.0,
#     "ingles": 54.0
#   },
#   "metricas_rendimiento": {
#     "promedio_acumulado": 3.47,
#     "materias_cursadas_total": 13,
#     "materias_perdidas_total": 8,
#     "materias_perdidas_por_departamento": {
#       "Dpto. Derecho": 6,
#       "Dpto. de Economía": 1,
#       "Dpto. Lenguas Extranjeras": 1
#     },
#     "materias_repetidas": 1
#   },
#   "estado": {
#     "becado": "No becado",
#     "graduado": 0,
#     "desertor": 0
#   },
#   "periodo_info": {
#     "ultimo_periodo": 202510
#   },
#   "materias_cursadas": [
#     {
#       "materia": "COMPETENCIA COMUNICATIVA II",
#       "codigo_materia": "CAS3030",
#       "categoria": "Dpto. Español",
#       "periodo": 202510,
#       "nota": 4.9,
#       "retirada": 0
#     },
#     {
#       "materia": "SOCIOLOGÍA JURÍDICA",
#       "codigo_materia": "CSO7150",
#       "categoria": "Dpto. Derecho",
#       "periodo": 202510,
#       "nota": 2.7,
#       "retirada": 0
#     },
#     {
#       "materia": "INTRODUCCION A LA ECONOMIA",
#       "codigo_materia": "ECO0010",
#       "categoria": "Dpto. de Economía",
#       "periodo": 202430,
#       "nota": 4.3,
#       "retirada": 1
#     },
#     {
#       "materia": "HISTORIA DEL DERECHO",
#       "codigo_materia": "HIS1020",
#       "categoria": "Dpto. Derecho",
#       "periodo": 202510,
#       "nota": 3.4,
#       "retirada": 0
#     },
#     {
#       "materia": "HISTORIA DEL DERECHO",
#       "codigo_materia": "HIS1020",
#       "categoria": "Dpto. Derecho",
#       "periodo": 202430,
#       "nota": 2.5,
#       "retirada": 1
#     },
#     {
#       "materia": "EXIGENCIA  INGLES II",
#       "codigo_materia": "IGL4895",
#       "categoria": "Dpto. Lenguas Extranjeras",
#       "periodo": 202430,
#       "nota": 4.1,
#       "retirada": 1
#     },
#     {
#       "materia": "EXIGENCIA  INGLES III",
#       "codigo_materia": "IGL4900",
#       "categoria": "Dpto. Lenguas Extranjeras",
#       "periodo": 202510,
#       "nota": 3.8,
#       "retirada": 0
#     },
#     {
#       "materia": "PERSONAS",
#       "codigo_materia": "LEY1031",
#       "categoria": "Dpto. Derecho",
#       "periodo": 202430,
#       "nota": 3.6,
#       "retirada": 1
#     },
#     {
#       "materia": "BIENES",
#       "codigo_materia": "LEY1060",
#       "categoria": "Dpto. Derecho",
#       "periodo": 202510,
#       "nota": 3.7,
#       "retirada": 0
#     },
#     {
#       "materia": "TEORIA Y ORG. DEL ESTADO",
#       "codigo_materia": "LEY1080",
#       "categoria": "Dpto. Derecho",
#       "periodo": 202510,
#       "nota": 2.8,
#       "retirada": 0
#     },
#     {
#       "materia": "TEORIA CONS. E INST. POLITICAS",
#       "codigo_materia": "LEY2021",
#       "categoria": "Dpto. Derecho",
#       "periodo": 202430,
#       "nota": 3.1,
#       "retirada": 1
#     },
#     {
#       "materia": "INTERPRETACION CONST Y LEGAL",
#       "codigo_materia": "LEY4640",
#       "categoria": "Dpto. Derecho",
#       "periodo": 202510,
#       "nota": 3.0,
#       "retirada": 0
#     },
#     {
#       "materia": "TEORIA DEL DERECHO",
#       "codigo_materia": "LEY4715",
#       "categoria": "Dpto. Derecho",
#       "periodo": 202430,
#       "nota": 3.3,
#       "retirada": 1
#     }
#   ]
# }

# %% [markdown]
# # concetar a azure

# %%
#pip install pymongo pandas dnspython

# %%
import json
from pymongo import MongoClient
import time

# %%
CONNECTION_STRING = "mongodb://proyectoestudiantes:suVKLoKoqjCxdeRnmZH7IICunDq54Ed33zaKcNzPBdxI2PVaohC0veT5diWHmsojaQCW6r2qohC9ACDbu5vPqQ==@proyectoestudiantes.mongo.cosmos.azure.com:10255/?ssl=true&replicaSet=globaldb&retrywrites=false&maxIdleTimeMS=120000&appName=@proyectoestudiantes@"

# Nombres
DATABASE_NAME = "Estudiantes"
COLLECTION_NAME = "Estudiantes_Materias"
JSON_FILE = "estudiantes_documentos.json"

# %%
client = MongoClient(CONNECTION_STRING)

# Probar la conexión
try:
    client.server_info()
    print("✓ Conexión exitosa")
except Exception as e:
    print(f" Error: {e}")
    exit()
# Out:
# C:\Users\claud\AppData\Local\Temp\ipykernel_36176\4213219313.py:1: UserWarning: You appear to be connected to a CosmosDB cluster. For more information regarding feature compatibility and support please visit https://www.mongodb.com/supportability/cosmosdb
#   client = MongoClient(CONNECTION_STRING)
# ✓ Conexión exitosa

# %%
db = client[DATABASE_NAME]
collection = db[COLLECTION_NAME]

# LIMPIAR la colección antes de insertar datos nuevos
resultado_eliminacion = collection.delete_many({})
print(f"✓ Documentos eliminados: {resultado_eliminacion.deleted_count}")
# Out:
# ✓ Documentos eliminados: 0

# %%
# Leer archivo JSON

with open(JSON_FILE, 'r', encoding='utf-8') as archivo:
    documentos = json.load(archivo)

# %%
# Insertar documentos

for documento in tqdm(documentos, desc="Insertando documentos"):
    try:
        collection.insert_one(documento)
    except Exception as e:
      pass
# Out:
# Insertando documentos: 100%|██████████| 10226/10226 [19:28<00:00,  8.75it/s]
# Insertando documentos: 100%|██████████| 10226/10226 [19:28<00:00,  8.75it/s]

# %%
# Contar total
total = collection.count_documents({})
print(f"\nTotal documentos: {total}")

# Contar desertores
desertores = collection.count_documents({"estado.desertor": 1})
no_desertores = collection.count_documents({"estado.desertor": 0})

print(f"Desertores: {desertores} ({desertores/total*100:.1f}%)")
print(f"No desertores: {no_desertores} ({no_desertores/total*100:.1f}%)")
# Out:
# ---------------------------------------------------------------------------
# InvalidOperation                          Traceback (most recent call last)
# Cell In[79], line 2
#       1 # Contar total
# ----> 2 total = collection.count_documents({})
#       3 print(f"\nTotal documentos: {total}")
#       5 # Contar desertores
#
# File c:\Users\claud\anaconda3\envs\Basico\Lib\site-packages\pymongo\synchronous\collection.py:2163, in Collection.count_documents(self, filter, session, comment, **kwargs)
#    2160         return 0
#    2161     return result["n"]
# -> 2163 return self._retryable_non_cursor_read(_cmd, session, _Op.COUNT)
#
# File c:\Users\claud\anaconda3\envs\Basico\Lib\site-packages\pymongo\synchronous\collection.py:2177, in Collection._retryable_non_cursor_read(self, func, session, operation)
#    2175 client = self._database.client
#    2176 with client._tmp_session(session) as s:
# -> 2177     return client._retryable_read(func, self._read_preference_for(s), s, operation)
#
# File c:\Users\claud\anaconda3\envs\Basico\Lib\site-packages\pymongo\synchronous\mongo_client.py:2047, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    2042 # Ensure that the client supports retrying on reads and there is no session in
#    2043 # transaction, otherwise, we will not support retry behavior for this call.
#    2044 retryable = bool(
#    2045     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    2046 )
# -> 2047 return self._retry_internal(
#    2048     func,
#    2049     session,
#    2050     None,
#    2051     operation,
#    2052     is_read=True,
#    2053     address=address,
#    2054     read_pref=read_pref,
#    2055     retryable=retryable,
#    2056     operation_id=operation_id,
#    2057 )
#
# File c:\Users\claud\anaconda3\envs\Basico\Lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File c:\Users\claud\anaconda3\envs\Basico\Lib\site-packages\pymongo\synchronous\mongo_client.py:2014, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1977 @_csot.apply
#    1978 def _retry_internal(
#    1979     self,
#    (...)   1988     operation_id: Optional[int] = None,
#    1989 ) -> T:
#    1990     """Internal retryable helper for all client transactions.
#    1991
#    1992     :param func: Callback function we want to retry
#    (...)   2001     :return: Output of the calling func()
#    2002     """
#    2003     return _ClientConnectionRetryable(
#    2004         mongo_client=self,
#    2005         func=func,
#    2006         bulk=bulk,
#    2007         operation=operation,
#    2008         is_read=is_read,
#    2009         session=session,
#    2010         read_pref=read_pref,
#    2011         address=address,
#    2012         retryable=retryable,
#    2013         operation_id=operation_id,
# -> 2014     ).run()
#
# File c:\Users\claud\anaconda3\envs\Basico\Lib\site-packages\pymongo\synchronous\mongo_client.py:2765, in _ClientConnectionRetryable.run(self)
#    2763 self._check_last_error(check_csot=True)
#    2764 try:
# -> 2765     return self._read() if self._is_read else self._write()
#    2766 except ServerSelectionTimeoutError:
#    2767     # The application may think the write was never attempted
#    2768     # if we raise ServerSelectionTimeoutError on the retry
#    2769     # attempt. Raise the original exception instead.
#    2770     self._check_last_error()
#
# File c:\Users\claud\anaconda3\envs\Basico\Lib\site-packages\pymongo\synchronous\mongo_client.py:2910, in _ClientConnectionRetryable._read(self)
#    2905 def _read(self) -> T:
#    2906     """Wrapper method for read-type retryable client executions
#    2907
#    2908     :return: Output for func()'s call
#    2909     """
# -> 2910     self._server = self._get_server()
#    2911     assert self._read_pref is not None, "Read Preference required on read calls"
#    2912     with self._client._conn_from_server(self._read_pref, self._server, self._session) as (
#    2913         conn,
#    2914         read_pref,
#    2915     ):
#
# File c:\Users\claud\anaconda3\envs\Basico\Lib\site-packages\pymongo\synchronous\mongo_client.py:2858, in _ClientConnectionRetryable._get_server(self)
#    2853 def _get_server(self) -> Server:
#    2854     """Retrieves a server object based on provided object context
#    2855
#    2856     :return: Abstraction to connect to server
#    2857     """
# -> 2858     return self._client._select_server(
#    2859         self._server_selector,
#    2860         self._session,
#    2861         self._operation,
#    2862         address=self._address,
#    2863         deprioritized_servers=self._deprioritized_servers,
#    2864         operation_id=self._operation_id,
#    2865     )
#
# File c:\Users\claud\anaconda3\envs\Basico\Lib\site-packages\pymongo\synchronous\mongo_client.py:1833, in MongoClient._select_server(self, server_selector, session, operation, address, deprioritized_servers, operation_id)
#    1831             raise AutoReconnect("server %s:%s no longer available" % address)  # noqa: UP031
#    1832     else:
# -> 1833         server = topology.select_server(
#    1834             server_selector,
#    1835             operation,
#    1836             deprioritized_servers=deprioritized_servers,
#    1837             operation_id=operation_id,
#    1838         )
#    1839     return server
#    1840 except PyMongoError as exc:
#    1841     # Server selection errors in a transaction are transient.
#
# File c:\Users\claud\anaconda3\envs\Basico\Lib\site-packages\pymongo\synchronous\topology.py:409, in Topology.select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     399 def select_server(
#     400     self,
#     401     selector: Callable[[Selection], Selection],
#    (...)    406     operation_id: Optional[int] = None,
#     407 ) -> Server:
#     408     """Like select_servers, but choose a random server if several match."""
# --> 409     server = self._select_server(
#     410         selector,
#     411         operation,
#     412         server_selection_timeout,
#     413         address,
#     414         deprioritized_servers,
#     415         operation_id=operation_id,
#     416     )
#     417     if _csot.get_timeout():
#     418         _csot.set_rtt(server.description.min_round_trip_time)
#
# File c:\Users\claud\anaconda3\envs\Basico\Lib\site-packages\pymongo\synchronous\topology.py:387, in Topology._select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     378 def _select_server(
#     379     self,
#     380     selector: Callable[[Selection], Selection],
#    (...)    385     operation_id: Optional[int] = None,
#     386 ) -> Server:
# --> 387     servers = self.select_servers(
#     388         selector, operation, server_selection_timeout, address, operation_id
#     389     )
#     390     servers = _filter_servers(servers, deprioritized_servers)
#     391     if len(servers) == 1:
#
# File c:\Users\claud\anaconda3\envs\Basico\Lib\site-packages\pymongo\synchronous\topology.py:294, in Topology.select_servers(self, selector, operation, server_selection_timeout, address, operation_id)
#     291     self.cleanup_monitors()
#     293 with self._lock:
# --> 294     server_descriptions = self._select_servers_loop(
#     295         selector, server_timeout, operation, operation_id, address
#     296     )
#     298     return [
#     299         cast(Server, self.get_server_by_address(sd.address)) for sd in server_descriptions
#     300     ]
#
# File c:\Users\claud\anaconda3\envs\Basico\Lib\site-packages\pymongo\synchronous\topology.py:361, in Topology._select_servers_loop(self, selector, timeout, operation, operation_id, address)
#     349     _debug_log(
#     350         _SERVER_SELECTION_LOGGER,
#     351         message=_ServerSelectionStatusMessage.WAITING,
#    (...)    357         remainingTimeMS=int(1000 * (end_time - time.monotonic())),
#     358     )
#     359     logged_waiting = True
# --> 361 self._ensure_opened()
#     362 self._request_check_all()
#     364 # Release the lock and wait for the topology description to
#     365 # change, or for a timeout. We won't miss any changes that
#     366 # came after our most recent apply_selector call, since we've
#     367 # held the lock until now.
#
# File c:\Users\claud\anaconda3\envs\Basico\Lib\site-packages\pymongo\synchronous\topology.py:789, in Topology._ensure_opened(self)
#     784 """Start monitors, or restart after a fork.
#     785
#     786 Hold the lock when calling this.
#     787 """
#     788 if self._closed:
# --> 789     raise InvalidOperation("Cannot use MongoClient after close")
#     791 if not self._opened:
#     792     self._opened = True
#
# InvalidOperation: Cannot use MongoClient after close

# %%
# Contar becados
becados = collection.count_documents({"estado.becado": "No becado"})
print(f"Becados: {becados}")

# Mostrar un ejemplo
# Out:
# Becados: 6864

# %%
print("\nDocumento de ejemplo:")
ejemplo = collection.find_one({})
print(f"  ID: {ejemplo['_id']}")
print(f"  Programa: {ejemplo['academico']['programa']}")
print(f"  Desertor: {ejemplo['estado']['desertor']}")
# Out:
# Documento de ejemplo:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[30], line 2
#       1 print("\nDocumento de ejemplo:")
# ----> 2 ejemplo = collection.find_one({})
#       3 print(f"  ID: {ejemplo['_id']}")
#       4 print(f"  Programa: {ejemplo['academico']['programa']}")
#
# File c:\Users\claud\anaconda3\envs\Basico\Lib\site-packages\pymongo\synchronous\collection.py:1755, in Collection.find_one(self, filter, *args, **kwargs)
#    1753     filter = {"_id": filter}
#    1754 cursor = self.find(filter, *args, **kwargs)
# -> 1755 for result in cursor.limit(-1):
#    1756     return result
#    1757 return None
#
# File c:\Users\claud\anaconda3\envs\Basico\Lib\site-packages\pymongo\synchronous\cursor.py:1289, in Cursor.__next__(self)
#    1288 def __next__(self) -> _DocumentType:
# -> 1289     return self.next()
#
# File c:\Users\claud\anaconda3\envs\Basico\Lib\site-packages\pymongo\synchronous\cursor.py:1265, in Cursor.next(self)
#    1263 if self._empty:
#    1264     raise StopIteration
# -> 1265 if len(self._data) or self._refresh():
#    1266     return self._data.popleft()
#    1267 else:
#
# File c:\Users\claud\anaconda3\envs\Basico\Lib\site-packages\pymongo\synchronous\cursor.py:1213, in Cursor._refresh(self)
#    1191         raise InvalidOperation(
#    1192             "Passing a 'hint' is required when using the min/max query"
#    1193             " option to ensure the query utilizes the correct index"
#    1194         )
#    1195     q = self._query_class(
#    1196         self._query_flags,
#    1197         self._collection.database.name,
#    (...)   1211         self._exhaust,
#    1212     )
# -> 1213     self._send_message(q)
#    1214 elif self._id:  # Get More
#    1215     if self._limit:
#
# File c:\Users\claud\anaconda3\envs\Basico\Lib\site-packages\pymongo\synchronous\cursor.py:1108, in Cursor._send_message(self, operation)
#    1105     raise InvalidOperation("exhaust cursors do not support auto encryption")
#    1107 try:
# -> 1108     response = client._run_operation(
#    1109         operation, self._unpack_response, address=self._address
#    1110     )
#    1111 except OperationFailure as exc:
#    1112     if exc.code in _CURSOR_CLOSED_ERRORS or self._exhaust:
#    1113         # Don't send killCursors because the cursor is already closed.
#
# File c:\Users\claud\anaconda3\envs\Basico\Lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File c:\Users\claud\anaconda3\envs\Basico\Lib\site-packages\pymongo\synchronous\mongo_client.py:1938, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1928     operation.reset()  # Reset op in case of retry.
#    1929     return server.run_operation(
#    1930         conn,
#    1931         operation,
#    (...)   1935         self,
#    1936     )
# -> 1938 return self._retryable_read(
#    1939     _cmd,
#    1940     operation.read_preference,
#    1941     operation.session,  # type: ignore[arg-type]
#    1942     address=address,
#    1943     retryable=isinstance(operation, _Query),
#    1944     operation=operation.name,
#    1945 )
#
# File c:\Users\claud\anaconda3\envs\Basico\Lib\site-packages\pymongo\synchronous\mongo_client.py:2047, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    2042 # Ensure that the client supports retrying on reads and there is no session in
#    2043 # transaction, otherwise, we will not support retry behavior for this call.
#    2044 retryable = bool(
#    2045     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    2046 )
# -> 2047 return self._retry_internal(
#    2048     func,
#    2049     session,
#    2050     None,
#    2051     operation,
#    2052     is_read=True,
#    2053     address=address,
#    2054     read_pref=read_pref,
#    2055     retryable=retryable,
#    2056     operation_id=operation_id,
#    2057 )
#
# File c:\Users\claud\anaconda3\envs\Basico\Lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File c:\Users\claud\anaconda3\envs\Basico\Lib\site-packages\pymongo\synchronous\mongo_client.py:2014, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1977 @_csot.apply
#    1978 def _retry_internal(
#    1979     self,
#    (...)   1988     operation_id: Optional[int] = None,
#    1989 ) -> T:
#    1990     """Internal retryable helper for all client transactions.
#    1991
#    1992     :param func: Callback function we want to retry
#    (...)   2001     :return: Output of the calling func()
#    2002     """
#    2003     return _ClientConnectionRetryable(
#    2004         mongo_client=self,
#    2005         func=func,
#    2006         bulk=bulk,
#    2007         operation=operation,
#    2008         is_read=is_read,
#    2009         session=session,
#    2010         read_pref=read_pref,
#    2011         address=address,
#    2012         retryable=retryable,
#    2013         operation_id=operation_id,
# -> 2014     ).run()
#
# File c:\Users\claud\anaconda3\envs\Basico\Lib\site-packages\pymongo\synchronous\mongo_client.py:2765, in _ClientConnectionRetryable.run(self)
#    2763 self._check_last_error(check_csot=True)
#    2764 try:
# -> 2765     return self._read() if self._is_read else self._write()
#    2766 except ServerSelectionTimeoutError:
#    2767     # The application may think the write was never attempted
#    2768     # if we raise ServerSelectionTimeoutError on the retry
#    2769     # attempt. Raise the original exception instead.
#    2770     self._check_last_error()
#
# File c:\Users\claud\anaconda3\envs\Basico\Lib\site-packages\pymongo\synchronous\mongo_client.py:2926, in _ClientConnectionRetryable._read(self)
#    2918 if self._retrying:
#    2919     _debug_log(
#    2920         _COMMAND_LOGGER,
#    2921         message=f"Retrying read attempt number {self._attempt_number}",
#    (...)   2924         operationId=self._operation_id,
#    2925     )
# -> 2926 return self._func(self._session, self._server, conn, read_pref)
#
# File c:\Users\claud\anaconda3\envs\Basico\Lib\site-packages\pymongo\synchronous\mongo_client.py:1929, in MongoClient._run_operation.<locals>._cmd(_session, server, conn, read_preference)
#    1922 def _cmd(
#    1923     _session: Optional[ClientSession],
#    1924     server: Server,
#    1925     conn: Connection,
#    1926     read_preference: _ServerMode,
#    1927 ) -> Response:
#    1928     operation.reset()  # Reset op in case of retry.
# -> 1929     return server.run_operation(
#    1930         conn,
#    1931         operation,
#    1932         read_preference,
#    1933         self._event_listeners,
#    1934         unpack_res,
#    1935         self,
#    1936     )
#
# File c:\Users\claud\anaconda3\envs\Basico\Lib\site-packages\pymongo\synchronous\helpers.py:47, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      44 from pymongo.synchronous.pool import Connection
#      46 try:
# ---> 47     return func(*args, **kwargs)
#      48 except OperationFailure as exc:
#      49     if no_reauth:
#
# File c:\Users\claud\anaconda3\envs\Basico\Lib\site-packages\pymongo\synchronous\server.py:227, in Server.run_operation(self, conn, operation, read_preference, listeners, unpack_res, client)
#     225         first = docs[0]
#     226         operation.client._process_response(first, operation.session)  # type: ignore[misc, arg-type]
# --> 227         _check_command_response(first, conn.max_wire_version, pool_opts=conn.opts)  # type:ignore[has-type]
#     228 except Exception as exc:
#     229     duration = datetime.now() - start
#
# File c:\Users\claud\anaconda3\envs\Basico\Lib\site-packages\pymongo\helpers_shared.py:284, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error, pool_opts)
#     281 elif code == 43:
#     282     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 284 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: Error=16500, RetryAfterMs=818, Details='Response status code does not indicate success: TooManyRequests (429); Substatus: 3200; ActivityId: 3be0a20b-5e13-48a0-b02d-85c422368377; Reason: (
# Errors : [
#   "Request rate is large. More Request Units may be needed, so no changes were made. Please retry this request later. Learn more: http://aka.ms/cosmosdb-error-429"
# ]
# );, full error: {'ok': 0.0, 'errmsg': 'Error=16500, RetryAfterMs=818, Details=\'Response status code does not indicate success: TooManyRequests (429); Substatus: 3200; ActivityId: 3be0a20b-5e13-48a0-b02d-85c422368377; Reason: (\r\nErrors : [\r\n  "Request rate is large. More Request Units may be needed, so no changes were made. Please retry this request later. Learn more: http://aka.ms/cosmosdb-error-429"\r\n]\r\n);', 'code': 16500, 'codeName': 'RequestRateTooLarge'}

# %%
# Cerrar conexión
client.close()
